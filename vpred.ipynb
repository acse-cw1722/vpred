# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv
from read_data import *

# %%
paths = get_vid_path()
# Out:
# /Users/cw1722/Projects/video_pre/VIDEOS
# ['/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_6.mp4']
# ['/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_6.mp4', '/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_22.mp4']
# ['/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_6.mp4', '/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_22.mp4', '/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_36.mp4']
# ['/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_6.mp4', '/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_22.mp4', '/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_36.mp4', '/Users/cw1722/Projects/video_pre/VIDEOS/fire_Chimney_video_37.mp4']
# ...

# %%
X = build_data_set(paths)
# Out:
# 49

# %%
X.shape
# Out:
# (49, 16, 128, 128, 3)

# %%
X_train = X[:40,:,:,:,:]
X_test = X[40:,:,:,:,:]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (40, 16, 128, 128, 3)
# (9, 16, 128, 128, 3)
